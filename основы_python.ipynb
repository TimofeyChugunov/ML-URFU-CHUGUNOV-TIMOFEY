# %% [markdown]
# #Задача 1
# Написать функцию на вход которой подается строка, состоящая из латинских букв.
# Функция должна вернуть количество гласных букв (a, e, i, o, u) в этой строке. Написать тесты для кода

# %%
def count_vowels(s: str) -> int:
    vowels = 'aeiou'
    count = 0
    for char in s.lower():
        if char in vowels:
            count += 1
    return count

assert count_vowels('hello') == 2
assert count_vowels('world') == 1
assert count_vowels('python') == 1
assert count_vowels('') == 0
assert count_vowels('AEIOU') == 5
assert count_vowels('bcdfg') == 0

print('Все тесты пройдены')
# Out:
# Все тесты пройдены

# %% [markdown]
# # Задача 2
# Написать функцию на вход, которой подается строка. Функция должна вернуть true, если
# каждый символ в строке встречается только 1 раз, иначе должна вернуть false. Написать тесты для кода

# %%
def unique_str(s:str) -> bool:
    unique_symbols = []
    for char in s:
        if char not in unique_symbols:
            unique_symbols.append(char)
        else:
            print('Not unique symbol in str')
            return False
    return True


assert unique_str('hello') == False
assert unique_str('helo') == True
assert unique_str('') == True
assert unique_str('qwerty') == True
assert unique_str('Capuccino') == False

print('Все тесты пройдены')
# Out:
# Not unique symbol in str
# Not unique symbol in str

# %% [markdown]
# # Задача 3
# Написать функцию, которая принимает положительное число и возвращает количество
# бит равных 1 в этом числе. Написать тесты для кода

# %%
def count_ones(s:int) -> int:
    return bin(s).count('1')
    
assert count_ones(5) == 2
assert count_ones(7) == 3
assert count_ones(1) == 1
assert count_ones(15) == 4

print('Все тесты пройдены')
# Out:
# Все тесты пройдены

# %% [markdown]
# # Задача 4
# Написать функцию, которая принимает положительное число. Функция должна вернуть то,
# сколько раз необходимо перемножать цифры числа или результат перемножения, чтобы
# получилось число состоящее из одной цифры.
# Например, для входного числа:
# · 39 функция должна вернуть 3, так как 3*9=27 => 2*7=14 => 1*4=4
# · 4 функция должна вернуть 0, так как число уже состоит из одной цифры
# · 999 функция должна вернуть 4, так как 9*9*9=729 => 7*2*9=126 => 1*2*6=12 =>
# 1*2=2. Написать тесты для кода

# %%
def magic(n):
    if n < 10:
        return 0
    count = 0
    while n >= 10:
        result = 1
        for digit in str(n):
            result *= int(digit)
        n = result
        count += 1
    return count

assert magic(39) == 3
assert magic(4) == 0
assert magic(999) == 4
assert magic(25) == 2 
assert magic(10) == 1  

print("Все тесты пройдены")
# Out:
# Все тесты пройдены

# %% [markdown]
# # Задача 5
# Написать функцию, которая принимает два целочисленных вектора одинаковой длины и
# возвращает среднеквадратическое отклонение двух векторов. Написать тесты для кода

# %%
def mse(vec1, vec2):
    if len(vec1) != len(vec2):
        raise ValueError("Векторы должны быть одинаковой длины")
    n = len(vec1)
    squared_diffs = []
    for i in range(n):
        squared_diffs.append((vec1[i] - vec2[i]) ** 2)
    mse = sum(squared_diffs) / n
    return mse


assert mse([1, 2, 3], [1, 2, 3]) == 0
assert mse([1, 2, 3], [2, 2, 2]) == ((1-2)**2 + (2-2)**2 + (3-2)**2) / 3
assert mse([0, 0, 0], [1, 1, 1]) == 1
assert mse([1, 1, 1], [0, 0, 0]) == 1
print("Все тесты пройдены")
# Out:
# Все тесты пройдены

# %% [markdown]
# # Задача 6
# Написать функцию, принимающая целое положительное число. Функция должна вернуть
# строку вида “(n1**p1)(n2**p2)…(nk**pk)” представляющая разложение числа на простые
# множители (если pi == 1, то выводить только ni).
# Например, для числа 86240 функция должна вернуть “(2**5)(5)(7**2)(11)”. Написать тесты для кода

# %%
def prime_factorization(n: int) -> str:
    factors = {}
    divisor = 2
    while n > 1:
        while n % divisor == 0:
            factors[divisor] = factors.get(divisor, 0) + 1
            n //= divisor
        divisor += 1
    result = ''
    for prime in sorted(factors.keys()):
        power = factors[prime]
        if power == 1:
            result += f'({prime})'
        else:
            result += f'({prime}**{power})'
    return result

assert prime_factorization(86240) == '(2**5)(5)(7**2)(11)'
assert prime_factorization(13) == '(13)'
assert prime_factorization(60) == '(2**2)(3)(5)'
assert prime_factorization(1) == ''
assert prime_factorization(1024) == '(2**10)'

print("Все тесты пройдены")
# Out:
# Все тесты пройдены

# %% [markdown]
# # Задача 7
# Написать функцию, принимающая целое число n, задающее количество кубиков. Функция
# должна определить, можно ли из данного кол-ва кубиков построить пирамиду, то есть
# можно ли представить число n как 1^2+2^2+3^2+…+k^2. Если можно, то функция должна
# вернуть k, иначе строку “It is impossible”. Написать тесты для кода

# %%
def pyramid(n):
    total = 0
    k = 0
    while total < n:
        k += 1
        total += k ** 2
        if total == n:
            return k
    return "It is impossible"


assert pyramid(1) == 1      
assert pyramid(14) == 3     
assert pyramid(30) == 4    
assert pyramid(20) == "It is impossible" 
assert pyramid(55) == 5     

print("Все тесты пройдены")
# Out:
# Все тесты пройдены

# %% [markdown]
# # Задача 8
# Функция принимает на вход положительное число и определяет является ли оно сбалансированным, т.е. сумма цифр до средних равна сумме цифр после. Средними в случае нечетного числа цифр считать одну цифру, в случае четного - две средних. Написать тесты для кода

# %%
def is_balanced_number(n):
    s = str(n)
    length = len(s)
    if length == 1:
        return True  
    
    if length % 2 == 1:
        mid = length // 2
        left_sum = sum(int(digit) for digit in s[:mid])
        right_sum = sum(int(digit) for digit in s[mid+1:])
        return left_sum == right_sum
    
    else:
        mid1 = length // 2 - 1
        mid2 = length // 2
        left_sum = sum(int(digit) for digit in s[:mid1])
        right_sum = sum(int(digit) for digit in s[mid2+1:])
        return left_sum == right_sum

assert is_balanced_number(12321) == True  
assert is_balanced_number(123321) == True  
assert is_balanced_number(12345) == False
assert is_balanced_number(5) == True
assert is_balanced_number(11211) == True  
assert is_balanced_number(1234) == False

print("Все тесты пройдены")
